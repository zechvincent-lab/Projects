# %% [markdown]
# # **Intro**
#
# This project explores different time series forecasting approaches, including classical statistical methods, machine learning techniques, deep learning models, and hybrid approaches.
#
# The analysis is based on two datasets representing book sales for The Alchemist and The Very Hungry Caterpillar. The aim is to compare forecasting performance across different time series behaviours and assess model suitability for each case.
#
# The project focuses on building a full forecasting pipeline, including data preparation, stationarity testing, model development, evaluation, and interpretation of results from a business perspective.

# %% [markdown]
# # **Problem Statement**
#
# This project analyses sales data for two books from Nielsen’s dataset — The Very Hungry Caterpillar and The Alchemist — to identify trends and seasonal patterns that can be used to produce reliable forecasts.
#
# The objective is to evaluate how forecasting models can support practical business decisions, particularly in procurement, reordering, and inventory management.

# %% [markdown]
# # **Libraries**

# %%
# !pip install sktime "numpy<2.0" pmdarima tensorflow
# Out:
# Requirement already satisfied: sktime in /usr/local/lib/python3.12/dist-packages (0.40.1)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.12/dist-packages (1.26.4)
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.12/dist-packages (2.1.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.20.0)
# Requirement already satisfied: joblib<1.6,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from sktime) (1.5.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from sktime) (26.2)
# Requirement already satisfied: pandas<2.4.0,>=1.1 in /usr/local/lib/python3.12/dist-packages (from sktime) (2.2.2)
# Requirement already satisfied: scikit-base<0.14.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from sktime) (0.13.2)
# Requirement already satisfied: scikit-learn<1.8.0,>=0.24 in /usr/local/lib/python3.12/dist-packages (from sktime) (1.6.1)
# Requirement already satisfied: scipy<2.0.0,>=1.2 in /usr/local/lib/python3.12/dist-packages (from sktime) (1.16.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (3.0.12)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (0.14.6)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (2.5.0)
# Requirement already satisfied: setuptools!=50.0.0,>=42 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (75.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.19.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<2.4.0,>=1.1->sktime) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<2.4.0,>=1.1->sktime) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<2.4.0,>=1.1->sktime) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.5.20)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<1.8.0,>=0.24->sktime) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.14.5->pmdarima) (1.0.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)

# %%
# !pip install keras-tuner --upgrade
# Out:
# Collecting keras-tuner
#   Using cached keras_tuner-1.4.8-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (3.13.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (26.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (2.32.4)
# Collecting kt-legacy (from keras-tuner)
#   Using cached kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: grpcio in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (1.80.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (5.29.6)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from grpcio->keras-tuner) (4.15.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (3.16.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (0.19.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (3.15)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (2026.5.20)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras->keras-tuner) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras->keras-tuner) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Using cached keras_tuner-1.4.8-py3-none-any.whl (129 kB)
# Using cached kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.8 kt-legacy-1.0.5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.tsa.api as tsa
import pmdarima as pm
import tensorflow as tf
import sktime
import keras_tuner as kt
import math
import random
from sktime.forecasting.arima import AutoARIMA
from datetime import datetime, timedelta
from matplotlib.patches import Rectangle
import matplotlib.animation as animation
from matplotlib import animation
from matplotlib import rc
import matplotlib.ticker as mtick
import statsmodels.graphics.api as smgraphics # gives access to all plotting functions in statsmodels.
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.tsa.stattools import adfuller as adf
from statsmodels.tsa.seasonal import STL
from scipy.stats import boxcox
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.exponential_smoothing.ets import ETSModel
from pmdarima.arima import auto_arima
from statsmodels.tsa.stattools import acf
from sklearn.metrics import mean_squared_error
from sktime.forecasting.compose import (TransformedTargetForecaster, make_reduction)
from sktime.forecasting.model_selection import (ExpandingWindowSplitter, ForecastingGridSearchCV)
from sktime.performance_metrics.forecasting import MeanAbsolutePercentageError
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import root_mean_squared_error
from statsmodels.tsa.stattools import pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plt.rcParams["figure.figsize"] = (10, 5)
from sktime.forecasting.trend import PolynomialTrendForecaster
from sktime.transformations.series.detrend import Deseasonalizer, Detrender
from xgboost import XGBRegressor
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
from kerastuner.tuners import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters
from sklearn.model_selection import TimeSeriesSplit
import warnings
from os import error
import os
import shutil
from IPython.display import display
# Suppress all warnings.
warnings.filterwarnings("ignore")

print(" All libraries imported successfully!")
# Out:
#  All libraries imported successfully!

# %%
#setting the random seed to ensure reproducibility of results
seed = 42

random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# # **Preprocessing**

# %%
# Mount your drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_dictionary_UK  = pd.read_csv("data/book_sales.csv")

# %%
print(data_dictionary_UK.keys())
# Out:
# dict_keys(['F Adult Fiction', 'S Adult Non-Fiction Specialist', 'T Adult Non-Fiction Trade', "Y Children's, YA & Educational"])

# %%
data_dictionary_ISBN=pd.read_excel("data/book_sales.xlsx")

# %%
print(data_dictionary_ISBN.keys())
# Out:
# dict_keys(['F - Adult Fiction', 'S Adult Non-Fiction Specialist', 'T Adult Non-Fiction Trade', "Y Children's, YA & Educational"])

# %%
# Combine all sheets in data_dictionary_UK  into a single DataFrame with an extra column to identify the sheet
df_UK_weekly = pd.concat(
    [df.assign(Category=sheet_name) for sheet_name, df in data_dictionary_UK.items()],
    ignore_index=True
)

# %%
df_UK_weekly.head()
# Out:
#             ISBN            Title         Author  Interval   End Date  Volume  \
# 0  9780002261821  One For My Baby  Parsons, Tony    200513 2005-04-02       1
# 1  9780002261821  One For My Baby  Parsons, Tony    200503 2005-01-22       1
# 2  9780002261821  One For My Baby  Parsons, Tony    200422 2004-05-29       1
# 3  9780002261821  One For My Baby  Parsons, Tony    200415 2004-04-10       2
# 4  9780002261821  One For My Baby  Parsons, Tony    200404 2004-01-24       2
#
#    Value    ASP    RRP   Binding                   Imprint    Publisher Group  \
# 0  15.99  15.99  15.99  Hardback  HarperCollins Publishers  HarperCollins Grp
# 1  15.99  15.99  15.99  Hardback  HarperCollins Publishers  HarperCollins Grp
# 2  11.19  11.19  15.99  Hardback  HarperCollins Publishers  HarperCollins Grp
# 3  27.18  13.59  15.99  Hardback  HarperCollins Publishers  HarperCollins Grp
# 4  22.48  11.24  15.99  Hardback  HarperCollins Publishers  HarperCollins Grp
#
#                      Product Class         Category
# 0  F1.1 General & Literary Fiction  F Adult Fiction
# 1  F1.1 General & Literary Fiction  F Adult Fiction
# 2  F1.1 General & Literary Fiction  F Adult Fiction
# 3  F1.1 General & Literary Fiction  F Adult Fiction
# 4  F1.1 General & Literary Fiction  F Adult Fiction

# %%
# Combine all sheets in data_dictionary_ISBN  into a single DataFrame with an extra column to identify the sheet
df_ISBN = pd.concat(
    [df.assign(Category=sheet_name) for sheet_name, df in data_dictionary_ISBN.items()],
    ignore_index=True
)

# %%
df_ISBN.head()
# Out:
#             ISBN                                              Title  \
# 0  9780330375252                Bridget Jones's Diary (Film Tie-in)
# 1  9780140276336                                        White Teeth
# 2  9780006512134                                        Man and Boy
# 3  9780099280255                                       Brethren,The
# 4  9780552998727  Marrying The Mistress:an irresistible and grip...
#
#              Author                   Imprint    Publisher Group    RRP  \
# 0   Fielding, Helen                   Picador  Pan Macmillan Grp   8.99
# 1      Smith, Zadie         Penguin Books Ltd        Penguin Grp   9.99
# 2     Parsons, Tony  HarperCollins Publishers  HarperCollins Grp   8.99
# 3     Grisham, John               Arrow Books   Random House Grp   6.99
# 4  Trollope, Joanna                Black Swan     Transworld Grp  10.99
#
#      Binding Publication Date                     Product Class  \
# 0  Paperback       2001-03-23   F1.1 General & Literary Fiction
# 1  Paperback       2001-01-25   F1.1 General & Literary Fiction
# 2  Paperback       2000-03-06   F1.1 General & Literary Fiction
# 3  Paperback       2000-12-27  F2.1 Crime, Thriller & Adventure
# 4  Paperback       2001-02-01   F1.1 General & Literary Fiction
#
#   Country of Publication           Category
# 0         United Kingdom  F - Adult Fiction
# 1         United Kingdom  F - Adult Fiction
# 2         United Kingdom  F - Adult Fiction
# 3         United Kingdom  F - Adult Fiction
# 4         United Kingdom  F - Adult Fiction

# %% [markdown]
# Note that the data provided is weekly data.
#
# If no sales happened in a particular week, there will be no data representation for that week. This means that the data is not at fixed intervals.
#
# As a result, resample the data and fill in missing values with 0, such that even weeks with 0 sales is represented.
#
# Convert the ISBNs to a string value.
#
# Convert date to datetime object. (Recall that setting the date as the index has several advantages for time series handling.)

# %%
#replace spaces with underscores across all column names
df_UK_weekly.columns = df_UK_weekly.columns.str.replace(' ', '_')
df_ISBN.columns = df_ISBN.columns.str.replace(' ', '_')

# %%
# Convert ISBN to string
df_UK_weekly['ISBN'] = df_UK_weekly['ISBN'].astype(str)

# %%
df_ISBN['ISBN'] = df_ISBN['ISBN'].astype(str)

# %%
# Ensure End Date is datetime and set as index
df_UK_weekly['End_Date'] = pd.to_datetime(df_UK_weekly['End_Date'])

# %%
# Set 'End_Date' as the index
df_UK_weekly.set_index('End_Date', inplace=True)

# %%
df_UK_weekly.head()
# Out:
#                      ISBN            Title         Author  Interval  Volume  \
# End_Date
# 2005-04-02  9780002261821  One For My Baby  Parsons, Tony    200513       1
# 2005-01-22  9780002261821  One For My Baby  Parsons, Tony    200503       1
# 2004-05-29  9780002261821  One For My Baby  Parsons, Tony    200422       1
# 2004-04-10  9780002261821  One For My Baby  Parsons, Tony    200415       2
# 2004-01-24  9780002261821  One For My Baby  Parsons, Tony    200404       2
#
#             Value    ASP    RRP   Binding                   Imprint  \
# End_Date
# 2005-04-02  15.99  15.99  15.99  Hardback  HarperCollins Publishers
# 2005-01-22  15.99  15.99  15.99  Hardback  HarperCollins Publishers
# 2004-05-29  11.19  11.19  15.99  Hardback  HarperCollins Publishers
# 2004-04-10  27.18  13.59  15.99  Hardback  HarperCollins Publishers
# 2004-01-24  22.48  11.24  15.99  Hardback  HarperCollins Publishers
#
#               Publisher_Group                    Product_Class  \
# End_Date
# 2005-04-02  HarperCollins Grp  F1.1 General & Literary Fiction
# 2005-01-22  HarperCollins Grp  F1.1 General & Literary Fiction
# 2004-05-29  HarperCollins Grp  F1.1 General & Literary Fiction
# 2004-04-10  HarperCollins Grp  F1.1 General & Literary Fiction
# 2004-01-24  HarperCollins Grp  F1.1 General & Literary Fiction
#
#                    Category
# End_Date
# 2005-04-02  F Adult Fiction
# 2005-01-22  F Adult Fiction
# 2004-05-29  F Adult Fiction
# 2004-04-10  F Adult Fiction
# 2004-01-24  F Adult Fiction

# %%
df_UK_weekly.shape
# Out:
# (227224, 13)

# %%
# Sort the dataframe chronologically by the End_Date index
df_UK_weekly.sort_index(inplace=True)

# %%
df_UK_weekly.head()
# Out:
#                      ISBN                                              Title  \
# End_Date
# 2001-01-06  9781841461502                 KS2 English Study Book - Ages 7-11
# 2001-01-06  9780130125071                                Java How to Program
# 2001-01-06  9780563384311                      Delia's How To Cook: Book Two
# 2001-01-06  9780340704622                                   Business Studies
# 2001-01-06  9781841462301  KS3 Science Revision Guide – Higher (includes ...
#
#                                                        Author  Interval  \
# End_Date
# 2001-01-06                                          CGP Books    200101
# 2001-01-06                Deitel, Harvey M. & Deitel, Paul J.    200101
# 2001-01-06                                       Smith, Delia    200101
# 2001-01-06  Marcouse, Ian & Martin, Barry & Surridge, Malc...    200101
# 2001-01-06                                          CGP Books    200101
#
#             Volume     Value      ASP    RRP    Binding  \
# End_Date
# 2001-01-06     700   2370.97   3.3871   6.50  Paperback
# 2001-01-06      72   2267.40  31.4917  38.09   Hardback
# 2001-01-06    1878  21032.36  11.1993  20.00   Hardback
# 2001-01-06      90   1698.07  18.8674    NaN  Paperback
# 2001-01-06     463   1618.41   3.4955   6.50   Hardback
#
#                                               Imprint  \
# End_Date
# 2001-01-06  Coordination Group Publications Ltd (CGP)
# 2001-01-06                              Prentice-Hall
# 2001-01-06                   BBC Books (Random House)
# 2001-01-06                     Hodder & Stoughton Ltd
# 2001-01-06  Coordination Group Publications Ltd (CGP)
#
#                             Publisher_Group  \
# End_Date
# 2001-01-06  Coordination Group Publications
# 2001-01-06      Pearson Education: Prof Grp
# 2001-01-06                 Random House Grp
# 2001-01-06           Hodder & Stoughton Grp
# 2001-01-06  Coordination Group Publications
#
#                                                 Product_Class  \
# End_Date
# 2001-01-06  Y5.1 School Textbooks & Study Guides: Literatu...
# 2001-01-06        S10.2 Computing: Professional & Programming
# 2001-01-06                        T16.0 Food & Drink: General
# 2001-01-06  S4.0T Business, Accounting & Vocational: Textb...
# 2001-01-06  Y5.3 School Textbooks & Study Guides: Maths, S...
#
#                                   Category
# End_Date
# 2001-01-06  Y Children's, YA & Educational
# 2001-01-06  S Adult Non-Fiction Specialist
# 2001-01-06       T Adult Non-Fiction Trade
# 2001-01-06  S Adult Non-Fiction Specialist
# 2001-01-06  Y Children's, YA & Educational

# %%
df_UK_weekly.tail()
# Out:
#                      ISBN                         Title                Author  \
# End_Date
# 2024-07-20  9780099771517           Memoirs of a Geisha        Golden, Arthur
# 2024-07-20  9780241003008  Very Hungry Caterpillar, The           Carle, Eric
# 2024-07-20  9780006647553               Mog’s Bad Thing          Kerr, Judith
# 2024-07-20  9780006531203       In the Heart of the Sea  Philbrick, Nathaniel
# 2024-07-20  9780006550433    Bonesetter’s Daughter, The              Tan, Amy
#
#             Interval  Volume     Value      ASP    RRP    Binding  \
# End_Date
# 2024-07-20    202429      43    409.64   9.5265   9.99  Paperback
# 2024-07-20    202429    2574  11507.46   4.4707   7.99   Hardback
# 2024-07-20    202429      11     86.89   7.8991   7.99  Paperback
# 2024-07-20    202429       3     32.97  10.9900  10.99  Paperback
# 2024-07-20    202429       1      9.99   9.9900   9.99  Paperback
#
#                              Imprint    Publisher_Group  \
# End_Date
# 2024-07-20                   Vintage   Random House Grp
# 2024-07-20              Puffin Books        Penguin Grp
# 2024-07-20  HarperCollins Publishers  HarperCollins Grp
# 2024-07-20  HarperCollins Publishers  HarperCollins Grp
# 2024-07-20                  Flamingo  HarperCollins Grp
#
#                               Product_Class                        Category
# End_Date
# 2024-07-20  F1.1 General & Literary Fiction                 F Adult Fiction
# 2024-07-20               Y1.3 Picture Books  Y Children's, YA & Educational
# 2024-07-20               Y1.3 Picture Books  Y Children's, YA & Educational
# 2024-07-20  T5.3 History: Specific Subjects       T Adult Non-Fiction Trade
# 2024-07-20  F1.1 General & Literary Fiction                 F Adult Fiction

# %%
df_UK_weekly_g = (
    df_UK_weekly
    .groupby('ISBN')
    .resample('W')
    .sum()
    .fillna(0)
)

# Remove duplicate index level before reset_index
df_UK_weekly_g.index = df_UK_weekly_g.index.droplevel(0)  # drop 'ISBN' from index
df_UK_weekly_g = df_UK_weekly_g.reset_index()

# %%
df_UK_weekly_g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382871 entries, 0 to 382870
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   End_Date         382871 non-null  datetime64[ns]
#  1   ISBN             382871 non-null  object
#  2   Title            382871 non-null  object
#  3   Author           382871 non-null  object
#  4   Interval         382871 non-null  int64
#  5   Volume           382871 non-null  int64
#  6   Value            382871 non-null  float64
#  7   ASP              382871 non-null  float64
#  8   RRP              382871 non-null  float64
#  9   Binding          382871 non-null  object
#  10  Imprint          382871 non-null  object
#  11  Publisher_Group  382871 non-null  object
#  12  Product_Class    382871 non-null  object
#  13  Category         382871 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(8)
# memory usage: 40.9+ MB

# %%
df_UK_weekly_g.head()
# Out:
#     End_Date           ISBN                Title      Author  Interval  \
# 0 2001-01-07  9780001713031  Cat in the Hat, The  Seuss, Dr.    200101
# 1 2001-01-14  9780001713031  Cat in the Hat, The  Seuss, Dr.    200102
# 2 2001-01-21  9780001713031  Cat in the Hat, The  Seuss, Dr.    200103
# 3 2001-01-28  9780001713031  Cat in the Hat, The  Seuss, Dr.    200104
# 4 2001-02-04  9780001713031  Cat in the Hat, The  Seuss, Dr.    200105
#
#    Volume    Value     ASP   RRP    Binding  Imprint    Publisher_Group  \
# 0     522  2544.07  4.8737  4.99  Paperback  Collins  HarperCollins Grp
# 1     379  1842.21  4.8607  4.99  Paperback  Collins  HarperCollins Grp
# 2     393  1921.19  4.8885  4.99  Paperback  Collins  HarperCollins Grp
# 3     369  1785.31  4.8382  4.99  Paperback  Collins  HarperCollins Grp
# 4     423  2060.07  4.8701  4.99  Paperback  Collins  HarperCollins Grp
#
#                     Product_Class                        Category
# 0  Y4.2 Reference & Home Learning  Y Children's, YA & Educational
# 1  Y4.2 Reference & Home Learning  Y Children's, YA & Educational
# 2  Y4.2 Reference & Home Learning  Y Children's, YA & Educational
# 3  Y4.2 Reference & Home Learning  Y Children's, YA & Educational
# 4  Y4.2 Reference & Home Learning  Y Children's, YA & Educational

# %%
df_UK_weekly_g.tail()
# Out:
#          End_Date           ISBN                        Title Author  \
# 382866 2008-11-23              0                            0      0
# 382867 2008-11-30              0                            0      0
# 382868 2008-12-07  9781903840122  Wicked Book of Txt Tlk, The      0
# 382869 2008-12-14  9781903840122  Wicked Book of Txt Tlk, The      0
# 382870 2008-12-21  9781903840122  Wicked Book of Txt Tlk, The      0
#
#         Interval  Volume  Value   ASP   RRP    Binding       Imprint  \
# 382866         0       0   0.00  0.00  0.00          0             0
# 382867         0       0   0.00  0.00  0.00          0             0
# 382868    200849       1   0.40  0.40  1.99  Paperback  Buster Books
# 382869    200850       4   1.60  0.40  1.99  Paperback  Buster Books
# 382870    200851       2   2.38  1.19  1.99  Paperback  Buster Books
#
#            Publisher_Group                               Product_Class  \
# 382866                   0                                           0
# 382867                   0                                           0
# 382868  Michael O'Mara Grp  Y4.1 Children's General Interest & Leisure
# 382869  Michael O'Mara Grp  Y4.1 Children's General Interest & Leisure
# 382870  Michael O'Mara Grp  Y4.1 Children's General Interest & Leisure
#
#                               Category
# 382866                               0
# 382867                               0
# 382868  Y Children's, YA & Educational
# 382869  Y Children's, YA & Educational
# 382870  Y Children's, YA & Educational

# %%
# Set End_Date as index
df_UK_weekly_g.set_index('End_Date', inplace=True)

# Sort the dataframe chronologically
df_UK_weekly_g.sort_index(inplace=True)

# %%
df_UK_weekly_g.head()
# Out:
#                      ISBN                          Title  \
# End_Date
# 2001-01-07  9780001713031            Cat in the Hat, The
# 2001-01-07  9780003224764        Psychology for AS-level
# 2001-01-07  9780718144395  Return of the Naked Chef, The
# 2001-01-07  9780552998727          Marrying the Mistress
# 2001-01-07  9780115519772                   Highway Code
#
#                                                    Author  Interval  Volume  \
# End_Date
# 2001-01-07                                     Seuss, Dr.    200101     522
# 2001-01-07  Cardwell, Mike & Clark, Liz & Meldrum, Claire    200101      40
# 2001-01-07                                  Oliver, Jamie    200101    5742
# 2001-01-07                               Trollope, Joanna    200101     573
# 2001-01-07                                              0    200101    6185
#
#                Value      ASP    RRP    Binding                  Imprint  \
# End_Date
# 2001-01-07   2544.07   4.8737   4.99  Paperback                  Collins
# 2001-01-07    482.56  12.0640  12.99  Paperback      Collins Educational
# 2001-01-07  83782.37  14.5911  20.00   Hardback           Michael Joseph
# 2001-01-07   4005.18   6.9898  10.99  Paperback               Black Swan
# 2001-01-07   9168.94   1.4824   1.49  Paperback  Stationery Office Books
#
#                       Publisher_Group  \
# End_Date
# 2001-01-07          HarperCollins Grp
# 2001-01-07          HarperCollins Grp
# 2001-01-07                Penguin Grp
# 2001-01-07             Transworld Grp
# 2001-01-07  The Stationery Office Grp
#
#                                          Product_Class  \
# End_Date
# 2001-01-07              Y4.2 Reference & Home Learning
# 2001-01-07  S2.2T Psychology: Textbooks & Study Guides
# 2001-01-07                 T16.0 Food & Drink: General
# 2001-01-07             F1.1 General & Literary Fiction
# 2001-01-07            T12.2 Driving & The Highway Code
#
#                                   Category
# End_Date
# 2001-01-07  Y Children's, YA & Educational
# 2001-01-07  S Adult Non-Fiction Specialist
# 2001-01-07       T Adult Non-Fiction Trade
# 2001-01-07                 F Adult Fiction
# 2001-01-07       T Adult Non-Fiction Trade

# %%
df_UK_weekly_g.tail()
# Out:
#                      ISBN                            Title  \
# End_Date
# 2024-07-21  9780744523232       We're Going on a Bear Hunt
# 2024-07-21  9780552145060                          Journey
# 2024-07-21  9780006647553                  Mog’s Bad Thing
# 2024-07-21  9780440864141  Jacqueline Wilson Double Decker
# 2024-07-21  9780752844299         Arthur: The Seeing Stone
#
#                              Author  Interval  Volume    Value     ASP   RRP  \
# End_Date
# 2024-07-21           Rosen, Michael    202429    1556  6546.74  4.2074  7.99
# 2024-07-21          Steel, Danielle    202429       2    18.38  9.1900  9.99
# 2024-07-21             Kerr, Judith    202429      11    86.89  7.8991  7.99
# 2024-07-21       Wilson, Jacqueline    202429       5    38.91  7.7820  7.99
# 2024-07-21  Crossley-Holland, Kevin    202429       6    39.49  6.5817  6.99
#
#               Binding                                            Imprint  \
# End_Date
# 2024-07-21  Paperback                                   Walker Books Ltd
# 2024-07-21  Paperback                                        Corgi Books
# 2024-07-21  Paperback                           HarperCollins Publishers
# 2024-07-21  Paperback  Yearling (imprint of Random House Children's B...
# 2024-07-21  Paperback  Orion (an Imprint of The Orion Publishing Grou...
#
#                              Publisher_Group                    Product_Class  \
# End_Date
# 2024-07-21                        Walker Grp               Y1.3 Picture Books
# 2024-07-21                    Transworld Grp  F1.1 General & Literary Fiction
# 2024-07-21                 HarperCollins Grp               Y1.3 Picture Books
# 2024-07-21  Random House Childrens Books Grp          Y2.1 Children's Fiction
# 2024-07-21                         Orion Grp         Y2.2 Young Adult Fiction
#
#                                   Category
# End_Date
# 2024-07-21  Y Children's, YA & Educational
# 2024-07-21                 F Adult Fiction
# 2024-07-21  Y Children's, YA & Educational
# 2024-07-21  Y Children's, YA & Educational
# 2024-07-21  Y Children's, YA & Educational

# %% [markdown]
# Filter out the ISBNs (from all four tabs) wherein sales data exists beyond 2024-07-01.
#
# Show all the ISBNs that satisfy this criterion.

# %%
# Filter df_UK_weekly for records with sales data beyond 2024-07-01
df_UK_weekly_filtered = df_UK_weekly_g[df_UK_weekly_g.index > '2024-07-01']

# %%
# Get the list of ISBNs that meet the condition
isbn_filtered = df_UK_weekly_filtered['ISBN'].unique()

# %%
len(isbn_filtered )
# Out:
# 62

# %%
# Show the filtered ISBNs
print(isbn_filtered)
# Out:
# ['9780099244721' 0 '9780140276336' '9780099422587' '9780719559792'
#  '9781841461502' '9780006514213' '9780261103252' '9780140275421'
#  '9780349113609' '9780722532935' '9780752844299' '9780340766057'
#  '9780552998482' '9780552998444' '9780552997348' '9780349112763'
#  '9780552145954' '9781841462509' '9780552997034' '9780593048153'
#  '9780091867775' '9780099285823' '9780440864554' '9780552998000'
#  '9781841150437' '9780552998727' '9780140285215' '9780006647553'
#  '9780006514091' '9780099771517' '9780749397548' '9781841460307'
#  '9780140259506' '9780140276619' '9780140294231' '9780241003008'
#  '9780747268161' '9780340696767' '9780749395698' '9780099428558'
#  '9780744523232' '9780006531203' '9781841462400' '9781841462301'
#  '9780091816971' '9780140281293' '9780006512134' '9781841460406'
#  '9780440864141' '9780140295962' '9780099286578' '9780349114033'
#  '9780224060875' '9780340786055' '9780330355667' '9780007101887'
#  '9780552145060' '9780752846576' '9780006550433' '9780099286387'
#  '9780552145053']

# %% [markdown]
# Plot the data of all the ISBNs from the previous step by placing them in a loop.

# %%
# Create a plot grid (e.g., 8x8 grid for 64 slots, leaving some empty space for 61 ISBNs)
num_plots = len(isbn_filtered)
rows = (num_plots // 6) + (1 if num_plots % 6 != 0 else 0)  # Calculate number of rows needed
cols = 6  # 8 plots per row

# %%
# Create the figure and axes for subplots
fig, axes = plt.subplots(rows, cols, figsize=(20, 6 * rows))

# Flatten the axes array for easy indexing
axes = axes.flatten()

# Loop through each ISBN and plot the data from the original df_UK_weekly dataframe
for idx, isbn in enumerate(isbn_filtered):
    # Filter the original df_UK_weekly to get data for the current ISBN
    df_UK_weekly_isbn = df_UK_weekly_g[df_UK_weekly_g['ISBN'] == isbn]

    # Plot the data
    axes[idx].plot(df_UK_weekly_isbn.index, df_UK_weekly_isbn['Volume'], label=f'ISBN: {isbn}')
    axes[idx].set_title(f'ISBN: {isbn}')
    axes[idx].set_xlabel('Date')
    axes[idx].set_ylabel('Volume')
    axes[idx].legend()

# Remove unused subplots if there are any
for idx in range(num_plots, len(axes)):
    fig.delaxes(axes[idx])

# Adjust layout for better spacing
plt.tight_layout()

# %% [markdown]
# Volume has drascically decreesed from 2000 to 2004 before platuoing around 2008 to 2024 in most cases. Some books have a more gradual decline but most show the same downwards trend

# %% [markdown]
# We will be focusing on The Very Hungry Caterpillar and The Alchemist for further analysis. In this notebook we will just look at The Very Hungry Caterpillar then in a seperate notebook The Alchemist.
#
# Looking at the data after 2012-01-01

# %%
df_UK_weekly_g.head()
# Out:
#                      ISBN                          Title  \
# End_Date
# 2001-01-07  9780001713031            Cat in the Hat, The
# 2001-01-07  9780003224764        Psychology for AS-level
# 2001-01-07  9780718144395  Return of the Naked Chef, The
# 2001-01-07  9780552998727          Marrying the Mistress
# 2001-01-07  9780115519772                   Highway Code
#
#                                                    Author  Interval  Volume  \
# End_Date
# 2001-01-07                                     Seuss, Dr.    200101     522
# 2001-01-07  Cardwell, Mike & Clark, Liz & Meldrum, Claire    200101      40
# 2001-01-07                                  Oliver, Jamie    200101    5742
# 2001-01-07                               Trollope, Joanna    200101     573
# 2001-01-07                                              0    200101    6185
#
#                Value      ASP    RRP    Binding                  Imprint  \
# End_Date
# 2001-01-07   2544.07   4.8737   4.99  Paperback                  Collins
# 2001-01-07    482.56  12.0640  12.99  Paperback      Collins Educational
# 2001-01-07  83782.37  14.5911  20.00   Hardback           Michael Joseph
# 2001-01-07   4005.18   6.9898  10.99  Paperback               Black Swan
# 2001-01-07   9168.94   1.4824   1.49  Paperback  Stationery Office Books
#
#                       Publisher_Group  \
# End_Date
# 2001-01-07          HarperCollins Grp
# 2001-01-07          HarperCollins Grp
# 2001-01-07                Penguin Grp
# 2001-01-07             Transworld Grp
# 2001-01-07  The Stationery Office Grp
#
#                                          Product_Class  \
# End_Date
# 2001-01-07              Y4.2 Reference & Home Learning
# 2001-01-07  S2.2T Psychology: Textbooks & Study Guides
# 2001-01-07                 T16.0 Food & Drink: General
# 2001-01-07             F1.1 General & Literary Fiction
# 2001-01-07            T12.2 Driving & The Highway Code
#
#                                   Category
# End_Date
# 2001-01-07  Y Children's, YA & Educational
# 2001-01-07  S Adult Non-Fiction Specialist
# 2001-01-07       T Adult Non-Fiction Trade
# 2001-01-07                 F Adult Fiction
# 2001-01-07       T Adult Non-Fiction Trade

# %%
caterpillar_isbns = df_ISBN[df_ISBN['Title'].str.contains('caterpillar', case=False, na=False)]['ISBN'].astype(str).unique()

# %%
print("\n The Very Hungry Caterpillar ISBNs:")
print(caterpillar_isbns)
# Out:
#  The Very Hungry Caterpillar ISBNs:
# ['9780241003008' '9780140500875']

# %%
# Apply the date filter to df_UK_weekly
df_UK_weekly_post2012 = df_UK_weekly_g[df_UK_weekly_g.index > '2012-01-01']

# For The Very Hungry Caterpillar ISBNs
for isbn in caterpillar_isbns:
    volume_caterpillar = df_UK_weekly_post2012[df_UK_weekly_post2012['ISBN'] == isbn]['Volume'].sum()
    print(f"Volume for ISBN {isbn} (The Very Hungry Caterpillar) after 2012-01-01: {volume_caterpillar}")
# Out:
# Volume for ISBN 9780241003008 (The Very Hungry Caterpillar) after 2012-01-01: 883534
# Volume for ISBN 9780140500875 (The Very Hungry Caterpillar) after 2012-01-01: 2

# %% [markdown]
# We will be analysing:
#
# Volume for ISBN 9780241003008 (The Very Hungry Caterpillar) after 2012-01-01: 883534

# %%
# Directly filter df_UK_weekly_post2012 for the two ISBNs
df_UK_weekly_post2012 = df_UK_weekly_post2012[df_UK_weekly_post2012['ISBN'].isin(['9780241003008'])]

# %%
df_UK_weekly_post2012.head()
# Out:
#                      ISBN                         Title       Author  \
# End_Date
# 2012-01-08  9780241003008  Very Hungry Caterpillar, The  Carle, Eric
# 2012-01-15  9780241003008  Very Hungry Caterpillar, The  Carle, Eric
# 2012-01-22  9780241003008  Very Hungry Caterpillar, The  Carle, Eric
# 2012-01-29  9780241003008  Very Hungry Caterpillar, The  Carle, Eric
# 2012-02-05  9780241003008  Very Hungry Caterpillar, The  Carle, Eric
#
#             Interval  Volume    Value     ASP   RRP   Binding       Imprint  \
# End_Date
# 2012-01-08    201201     512  2522.13  4.9260  7.99  Hardback  Puffin Books
# 2012-01-15    201202     519  2473.31  4.7655  7.99  Hardback  Puffin Books
# 2012-01-22    201203     574  2757.83  4.8046  7.99  Hardback  Puffin Books
# 2012-01-29    201204     621  3072.66  4.9479  7.99  Hardback  Puffin Books
# 2012-02-05    201205    1140  4724.18  4.1440  7.99  Hardback  Puffin Books
#
#            Publisher_Group       Product_Class                        Category
# End_Date
# 2012-01-08     Penguin Grp  Y1.3 Picture Books  Y Children's, YA & Educational
# 2012-01-15     Penguin Grp  Y1.3 Picture Books  Y Children's, YA & Educational
# 2012-01-22     Penguin Grp  Y1.3 Picture Books  Y Children's, YA & Educational
# 2012-01-29     Penguin Grp  Y1.3 Picture Books  Y Children's, YA & Educational
# 2012-02-05     Penguin Grp  Y1.3 Picture Books  Y Children's, YA & Educational

# %%
df_UK_weekly_post2012.shape
# Out:
# (628, 13)

# %%
df_UK_weekly_post2012['Title'].unique()
# Out:
# array(['Very Hungry Caterpillar, The'], dtype=object)

# %%
# sorting the titles to read 'The Very Hungry Caterpillar'
df_UK_weekly_post2012['Title'] = df_UK_weekly_post2012['Title'].str.replace(r'^(.*), The$', r'The \1', regex=True)

# %%
df_UK_weekly_post2012['Title'].unique()
# Out:
# array(['The Very Hungry Caterpillar'], dtype=object)

# %%
df_UK_weekly_post2012['Volume'].isna().sum()
# Out:
# 0

# %%
# List of ISBNs to plot
isbns_to_plot = ['9780241003008']

# Loop through the ISBNs and plot
for isbn in isbns_to_plot:
    # Filter the df_UK_weekly_post2012 by the ISBN
    book_data = df_UK_weekly_post2012[df_UK_weekly_post2012['ISBN'] == isbn]

    # Get the unique title(s) for the ISBN
    title = book_data['Title'].unique()[0]
    print(title)

    # Plot the Volume over Time
    plt.figure(figsize=(10, 6))
    plt.plot(book_data.index, book_data['Volume'], label=f'Sales Volume - {title}')
    plt.title(f'Time Series of Sales Volume for {title}')
    plt.xlabel('Date')
    plt.ylabel('Sales Volume')
    plt.grid(True)
    plt.legend()
    plt.show()
# Out:
# The Very Hungry Caterpillar

# %% [markdown]
# **Monthly**

# %%
# Group by ISBN and resample by month-end, explicitly summing only the 'Volume' column.
book_monthly = df_UK_weekly_post2012.groupby('ISBN').resample('ME').agg({'Volume': 'sum'})

# The result of agg is a MultiIndex Series. Convert it back to a DataFrame and set End_Date as the main index.
book_monthly = book_monthly.reset_index()
book_monthly.set_index('End_Date', inplace=True)

# Sort by index to ensure chronological order
book_monthly.sort_index(inplace=True)

book_monthly.head(5)
# Out:
#                      ISBN  Volume
# End_Date
# 2012-01-31  9780241003008    2226
# 2012-02-29  9780241003008    4168
# 2012-03-31  9780241003008    2874
# 2012-04-30  9780241003008    3023
# 2012-05-31  9780241003008    2223

# %% [markdown]
# # **Helper Functions**

# %% [markdown]
# **Evaluating**

# %%
def evaluate_forecast(actual, forecast):

    mae = mean_absolute_error(actual, forecast)

    rmse = root_mean_squared_error(
        actual,
        forecast
    )

    mape = (
        mean_absolute_percentage_error(
            actual,
            forecast
        ) * 100
    )

    print(f"MAE: {mae:.2f}")
    print(f"RMSE: {rmse:.2f}")
    print(f"MAPE: {mape:.2f}%")

    return mae, rmse, mape

# %% [markdown]
# **Graphing**

# %%
#normal plot
def plot_forecast(
    train,
    test,
    forecast,
    title
):

    plt.figure(figsize=(12,6))

    plt.plot(train.index, train, label='Train')
    plt.plot(test.index, test, label='Actual')
    plt.plot(test.index, forecast, label='Forecast')

    plt.title(title)
    plt.legend()

    plt.show()

# %%
#zoomed in plot
def plot_forecast_zoom(train, test, forecast, title):

    plt.figure(figsize=(12,6))

    plt.plot(train.index, train, label='Train')
    plt.plot(test.index, test, label='Actual')
    plt.plot(test.index, forecast, label='Forecast')

    plt.title(title)
    plt.legend()

    plt.xlim(pd.Timestamp("2023-01-01"), None)

    plt.show()

# %% [markdown]
# **XGBoost**

# %%
def create_lag_features(y, lag=1):
    df = pd.DataFrame({'y': y})
    for i in range(1, lag + 1):
        df[f'lag_{i}'] = df['y'].shift(i)
    return df.dropna()

# %%
def recursive_forecast(history, horizon, predict_fn):
    preds = []
    history = list(history)
    for _ in range(horizon):
        pred = predict_fn(history)
        preds.append(pred)
        history.append(pred)
    return preds

# %% [markdown]
# **LSTM**

# %%
def create_input_sequence(lookback, forecast, squence_data):
  input_sequences = []
  output_sequences = []

  for i in range(lookback, len(squence_data) - forecast + 1):
    input_sequences.append(squence_data[i - lookback: i])
    output_sequences.append(squence_data[i: i + forecast])

  return np.array(input_sequences), np.array(output_sequences)

# %%
def tuned_model(hp):

    model = Sequential()
    model.add(LSTM(hp.Int('input_unit',min_value=4,max_value=128,step=8),return_sequences=True, input_shape=(lookback, 1)))
    for i in range(hp.Int('n_layers', 1, 4)):
        model.add(LSTM(hp.Int(f'lstm_{i}_units',min_value=4,max_value=128,step=8),return_sequences=True))
    model.add(LSTM(hp.Int('layer_2_neurons',min_value=4,max_value=128,step=8)))
    model.add(Dropout(hp.Float('Dropout_rate',min_value=0,max_value=0.5,step=0.1)))
    model.add(Dense(1, activation=hp.Choice('dense_activation',values=['relu', 'sigmoid'],default='relu')))
    model.compile(loss='mean_squared_error', optimizer='adam',metrics = ['mse'])
    return model

# %% [markdown]
# # **Decomposition**

# %%
#STL
stl = STL(df_UK_weekly_post2012['Volume'], period=12)
res = stl.fit()
fig = res.plot()

# %%
#Residuals
residuals = res.resid

# %%
#ACF
smgraphics.tsa.plot_acf(residuals, lags=100)
plt.show()

# %%
#PACF
smgraphics.tsa.plot_pacf(residuals, lags=100)
plt.show()

# %%
#Ljung-Box Test
ljungbox = acorr_ljungbox(residuals, lags=12, return_df=True)
print(ljungbox)
# Out:
#        lb_stat     lb_pvalue
# 1   157.022837  5.060107e-36
# 2   164.899344  1.557982e-36
# 3   171.332685  6.560746e-37
# 4   204.385344  4.284847e-43
# 5   246.157736  3.668157e-51
# 6   273.633551  3.620983e-56
# 7   282.909051  2.689892e-57
# 8   284.724421  7.312975e-57
# 9   284.797527  4.358735e-56
# 10  284.922143  2.381199e-55
# 11  299.219151  1.279438e-57
# 12  434.707324  1.664244e-85

# %%
#ADF Test
adf = adf(residuals)
print(f"ADF Statistic: {adf[0]}")
print(f"p-value: {adf[1]}")
# Out:
# ADF Statistic: -12.062000881160479
# p-value: 2.4571279921680615e-22

# %% [markdown]
# The Very Hungry Caterpillar shows an upward trend, with a strong seasonal pattern that remains consistent over time. The residuals are centred around zero, showing relatively little noise with a few outliers. This suggests that the trend and seasonality components capture most of the variation in the data. These characteristics indicate an additive decomposition.
# Next, we examine the ACF (Autocorrelation Function) and PACF (Partial Autocorrelation Function). The oscillating pattern of the lags, with a clear spike at lag 52, indicates a strong seasonal component. The PACF shows a cut-off after approximately two lags, although smaller spikes are still present at regular intervals.
# We also performed the ADF (Augmented Dickey–Fuller) test and the Ljung–Box test. The ADF test assesses whether the series is stationary. In this case, the p-value was below 0.05, leading us to reject the null hypothesis and conclude that the data is stationary. The Ljung–Box test checks for remaining autocorrelation. Again, the p-value was below 0.05, suggesting the series is not white noise and that autocorrelation is still present.

# %% [markdown]
# # **Auto ARIMA**

# %%
#split the data
ts_train = df_UK_weekly_post2012['Volume'][:-32]
ts_test = df_UK_weekly_post2012['Volume'][-32:]

# %%
ts_train
# Out:
# End_Date
# 2012-01-08     512
# 2012-01-15     519
# 2012-01-22     574
# 2012-01-29     621
# 2012-02-05    1140
#               ...
# 2023-11-12    2185
# 2023-11-19    2413
# 2023-11-26    2976
# 2023-12-03    2896
# 2023-12-10    2804
# Name: Volume, Length: 596, dtype: int64

# %%
ts_test
# Out:
# End_Date
# 2023-12-17    2794
# 2023-12-24    3527
# 2023-12-31    1151
# 2024-01-07    1273
# 2024-01-14    1421
# 2024-01-21    1679
# 2024-01-28    2062
# 2024-02-04    2595
# 2024-02-11    2755
# 2024-02-18    2558
# 2024-02-25    2198
# 2024-03-03    2675
# 2024-03-10    3496
# 2024-03-17    2605
# 2024-03-24    2427
# 2024-03-31    2746
# 2024-04-07    1831
# 2024-04-14    1926
# 2024-04-21    1748
# 2024-04-28    1648
# 2024-05-05    1002
# 2024-05-12    1635
# 2024-05-19    1917
# 2024-05-26    1997
# 2024-06-02    2200
# 2024-06-09    2306
# 2024-06-16    2197
# 2024-06-23    1985
# 2024-06-30    2097
# 2024-07-07    2448
# 2024-07-14    2482
# 2024-07-21    2574
# Name: Volume, dtype: int64

# %%
#Find the seasonal period
smgraphics.tsa.plot_acf(ts_train, lags=104)
plt.vlines(x=52, ymin=-0.5, ymax=0.5, colors='red', linestyle='--')
plt.show()

# %%
#Auto ARIMA
auto_arima = auto_arima(ts_train,
                                    start_p=0,
                                    start_q=0,
                                    max_p=1,
                                    max_q=1,
                                    start_P=0,
                                    start_Q=0,
                                    max_P=1,
                                    max_Q=1,
                                    D=1,
                                    information_criterion='aicc',
                                    seasonal=True,
                                    stepwise=True,
                                    suppress_warnings=True,
                                    error_action='ignore',
                                    m=52,
                                    trace=True)
print("\nAuto ARIMA Caterpillar model summary:")
print(auto_arima.summary())
# Out:
# Performing stepwise search to minimize aicc
#  ARIMA(0,0,0)(0,1,0)[52] intercept   : AICC=8230.156, Time=2.71 sec
#  ARIMA(1,0,0)(1,1,0)[52] intercept   : AICC=7741.456, Time=56.79 sec
#  ARIMA(0,0,1)(0,1,1)[52] intercept   : AICC=7862.084, Time=53.00 sec
#  ARIMA(0,0,0)(0,1,0)[52]             : AICC=8267.998, Time=1.32 sec
#  ARIMA(1,0,0)(0,1,0)[52] intercept   : AICC=7811.738, Time=3.11 sec
#  ARIMA(1,0,0)(1,1,1)[52] intercept   : AICC=inf, Time=85.44 sec
#  ARIMA(1,0,0)(0,1,1)[52] intercept   : AICC=7733.332, Time=32.89 sec
#  ARIMA(0,0,0)(0,1,1)[52] intercept   : AICC=8130.905, Time=33.42 sec
#  ARIMA(1,0,1)(0,1,1)[52] intercept   : AICC=7735.251, Time=45.26 sec
#  ARIMA(1,0,0)(0,1,1)[52]             : AICC=7748.988, Time=28.80 sec
#
# Best model:  ARIMA(1,0,0)(0,1,1)[52] intercept
# Total fit time: 342.778 seconds
#
# Auto ARIMA Caterpillar model summary:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  596
# Model:             SARIMAX(1, 0, 0)x(0, 1, [1], 52)   Log Likelihood               -3862.632
# Date:                              Fri, 05 Jun 2026   AIC                           7733.265
# Time:                                      12:14:34   BIC                           7750.460
# Sample:                                           0   HQIC                          7739.988
#                                               - 596
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     38.0492      8.557      4.447      0.000      21.278      54.820
# ar.L1          0.7183      0.019     37.451      0.000       0.681       0.756
# ma.S.L52      -0.4207      0.030    -14.071      0.000      -0.479      -0.362
# sigma2      8.473e+04   3035.828     27.910      0.000    7.88e+04    9.07e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):               582.97
# Prob(Q):                              0.84   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.53   Skew:                             0.08
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.07
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#Find the residuals for the best model
residuals_aa = auto_arima.resid()

#plot the residuals
residuals_aa.plot()
plt.axhline(0, linestyle='--')
plt.show()

# %%
#Histogram of residuals
residuals_aa.hist()
plt.show()

# %%
#ACF of residuals
smgraphics.tsa.plot_acf(residuals_aa, lags=104)
plt.show()

# %%
#Ljung-box Test on Residuals
ljungbox_aa = acorr_ljungbox(residuals_aa, lags=12, return_df=True)
print(ljungbox_aa)
# Out:
#        lb_stat     lb_pvalue
# 1    25.016709  5.683562e-07
# 2    35.797577  1.685213e-08
# 3    56.363346  3.514013e-12
# 4    72.445148  6.911023e-15
# 5    89.221250  9.792469e-18
# 6    99.486524  3.211228e-19
# 7   103.455939  2.082808e-19
# 8   115.064570  3.455141e-21
# 9   129.886584  1.251362e-23
# 10  141.112179  2.493292e-25
# 11  157.339573  4.695268e-28
# 12  160.252477  4.665716e-28

# %%
#Calculate forceasts and confidence intervals for the auto ARIMA model.
auto_arima_forecast = auto_arima.predict(n_periods=32)
auto_arima_ci = auto_arima.predict(n_periods=32, return_conf_int=True)[1]

#create a date index for the forecasts that matches the test set.
forecast_index = ts_test.index

#Plot the results.
plt.figure(figsize=(12, 6))
plt.plot(ts_train.index, ts_train, label='Training Data')
plt.plot(ts_test.index, ts_test, label='Test Data', color='orange')
plt.plot(forecast_index, auto_arima_forecast, label='Auto ARIMA Forecast', color='green')
plt.fill_between(forecast_index, auto_arima_ci[:, 0], auto_arima_ci[:, 1], color='green', alpha=0.2)
plt.title('Auto ARIMA Forecast for The Very Hungry Caterpillar')
plt.xlabel('Date')
plt.ylabel('Sales Volume')
plt.legend()
plt.show()

# %%
#Plot the results.
plt.figure(figsize=(12, 6))
plt.plot(ts_train.index, ts_train, label='Training Data')
plt.plot(ts_test.index, ts_test, label='Test Data', color='orange')
plt.plot(forecast_index, auto_arima_forecast, label='Auto ARIMA Forecast', color='green')
plt.fill_between(forecast_index, auto_arima_ci[:, 0], auto_arima_ci[:, 1], color='green', alpha=0.2)
plt.xlim(pd.Timestamp("2023-01-01", None))
plt.title('Auto ARIMA Forecast for The Very Hungry Caterpillar')
plt.xlabel('Date')
plt.ylabel('Sales Volume')
plt.legend()
plt.show()

# %%
#Evaluate
evaluate_forecast(ts_test, auto_arima_forecast)
# Out:
# MAE: 354.04
# RMSE: 430.98
# MAPE: 17.17%
# (354.03974177241514, 430.977113775528, 17.169507792803874)

# %% [markdown]
# Model:             SARIMAX(1, 0, 0)x(0, 1, [1], 52)
#
# For The Very Hungry Caterpillar, the auto ARIMA model performs well compared to the test data, closely following the overall pattern. However, the Ljung–Box test returns a p-value of 0.04, suggesting the presence of autocorrelation in the residuals. Despite this, the model remains reasonably accurate, with a MAPE score of 17%.

# %% [markdown]
# # **XGBoost**

# %%
#Hyper tuning parameters
window_lengths = [12, 26, 52]

param_grid = {
    "max_depth": [3, 4],
    "learning_rate": [0.05, 0.1],
    "n_estimators": [100, 200]
}

# %%
results_xgb = []

tscv_xgb = TimeSeriesSplit(n_splits=5)

for window_length in window_lengths:
  lagged_data = create_lag_features(df_UK_weekly_post2012['Volume'], lag=window_length)
  train_lagged = lagged_data.loc[lagged_data.index <= ts_train.index[-1]]

  x_train_xbg = train_lagged.drop(columns='y')
  y_train_xbg = train_lagged['y']

  for max_depth in param_grid['max_depth']:
    for learning_rate in param_grid['learning_rate']:
      for n_estimators in param_grid['n_estimators']:

        cv_maes = []

        for train_index, test_index in tscv_xgb.split(x_train_xbg):

          x_train_xbg_cv, x_test_xbg_cv = x_train_xbg.iloc[train_index], x_train_xbg.iloc[test_index]
          y_train_xbg_cv, y_test_xbg_cv = y_train_xbg.iloc[train_index], y_train_xbg.iloc[test_index]

          xgb_model = XGBRegressor(objective='reg:absoluteerror', max_depth=max_depth, learning_rate=learning_rate, n_estimators=n_estimators, random_state=seed)
          xgb_model.fit(x_train_xbg_cv, y_train_xbg_cv)

          y_pred_xbg_cv = xgb_model.predict(x_test_xbg_cv)

          cv_maes.append(mean_absolute_error(y_test_xbg_cv, y_pred_xbg_cv))

        results_xgb.append({
            'window_length': window_length,
            'max_depth': max_depth,
            'learning_rate': learning_rate,
            'n_estimators': n_estimators,
            'cv_mae': np.mean(cv_maes)
        })

# %%
#Best Model
results_xgb_df = pd.DataFrame(results_xgb)

best_params_xgb = results_xgb_df.loc[results_xgb_df['cv_mae'].idxmin()]

print("Best Hyperparameters for The Very Hungry Caterpillar:")
print(best_params_xgb)
# Out:
# Best Hyperparameters for The Very Hungry Caterpillar:
# window_length     26.000000
# max_depth          3.000000
# learning_rate      0.100000
# n_estimators     200.000000
# cv_mae           291.192816
# Name: 11, dtype: float64

# %%
best_window_xgb= int(best_params_xgb['window_length'])

lagged_data_xgb= create_lag_features(df_UK_weekly_post2012['Volume'], lag=best_window_xgb)
train_lagged_xgb = lagged_data_xgb.loc[lagged_data_xgb.index <= ts_train.index[-1]]

x_train_best_xbg = train_lagged_xgb.drop(columns='y')
y_train_best_xbg = train_lagged_xgb['y']

# %%
#Fit the model
best_xgb_model = XGBRegressor(objective='reg:squarederror', max_depth=int(best_params_xgb['max_depth']), learning_rate=best_params_xgb['learning_rate'], n_estimators=int(best_params_xgb["n_estimators"]), random_state=seed)
best_xgb_model.fit(x_train_best_xbg, y_train_best_xbg)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=200,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
#Forecast
def predict_next_xgb(history):
    x_input = np.array(history[-1:-best_window_xgb-1:-1]).reshape(1, -1)
    return best_xgb_model.predict(x_input)[0]

forecast_best_xgb = recursive_forecast(ts_train, 32, predict_next_xgb)

# %%
#plot
plot_forecast(ts_train, ts_test, forecast_best_xgb, 'XGBoost Forecast for The Very Hungry Caterpillar')

# %%
#zoomed plot
plot_forecast_zoom(ts_train, ts_test, forecast_best_xgb, 'XGBoost Forecast for The Very Hungry Caterpillar')

# %%
#Evaluate
evaluate_forecast(ts_test, forecast_best_xgb)
# Out:
# MAE: 609.74
# RMSE: 776.93
# MAPE: 26.89%
# (609.7440757751465, 776.9294458488744, 26.890618919754004)

# %% [markdown]
# XGBoost does not explicitly model time dependencies in the same way as traditional time series methods, and the results reflect this limitation. For The Very Hungry Caterpillar, the model achieves a MAPE score of 26.89%, which is reasonable, although the forecast tends to resemble a smoothed average of the data rather than capturing detailed temporal structure.

# %% [markdown]
# # **LSTM**

# %%
#Normalise the data
scaler = MinMaxScaler()
scaler.fit(ts_train.values.reshape(-1, 1))
ts_train_scaled = scaler.transform(ts_train.values.reshape(-1, 1))
ts_test_scaled = scaler.transform(ts_test.values.reshape(-1, 1))

# %%
lookback = 52

# %%
x, y = create_input_sequence(lookback, 1, ts_train_scaled)

# %%
print(x.shape)
print(y.shape)
# Out:
# (544, 52, 1)
# (544, 1, 1)

# %%
#convert to numpy
x = np.array(x)
y = np.array(y)

# %%
x_train_lstm = x[:-32]
y_train_lstm = y[:-32]
x_test_lstm = x[-32:]
y_test_lstm = y[-32:]

# %%
x_train_lstm.reshape((x_train_lstm.shape[0], x_train_lstm.shape[1], 1))
x_test_lstm.reshape((x_test_lstm.shape[0], x_test_lstm.shape[1], 1))
# Out:
# array([[[0.28087757],
#         [0.26760563],
#         [0.23320693],
#         ...,
#         [0.37648971],
#         [0.37080173],
#         [0.5067714 ]],
#
#        [[0.26760563],
#         [0.23320693],
#         [0.25893824],
#         ...,
#         [0.37080173],
#         [0.5067714 ],
#         [0.45151679]],
#
#        [[0.23320693],
#         [0.25893824],
#         [0.22101842],
#         ...,
#         [0.5067714 ],
#         [0.45151679],
#         [0.44609967]],
#
#        ...,
#
#        [[0.781961  ],
#         [0.80254605],
#         [0.84046587],
#         ...,
#         [0.52843987],
#         [0.53412784],
#         [0.59588299]],
#
#        [[0.80254605],
#         [0.84046587],
#         [0.8900325 ],
#         ...,
#         [0.53412784],
#         [0.59588299],
#         [0.74837486]],
#
#        [[0.84046587],
#         [0.8900325 ],
#         [1.        ],
#         ...,
#         [0.59588299],
#         [0.74837486],
#         [0.72670639]]])

# %%
tuner = kt.RandomSearch(
    tuned_model,
    objective='mse',
    max_trials=10,
    executions_per_trial=1,
    directory='lstm_tuning',
    project_name='sales_forecast_tuned',
    seed=seed
)

# %%
tuner.search(
    x=x_train_lstm,
    y=y_train_lstm,
    epochs=20,
    validation_split=0.2,
    batch_size=32,
    verbose=1
)
# Out:
# Trial 10 Complete [00h 00m 43s]
# mse: 0.016439929604530334
#
# Best mse So Far: 0.016439929604530334
# Total elapsed time: 00h 07m 36s

# %%
best_lstm_model = tuner.get_best_models(num_models=1)[0]

best_hp_lstm_model = tuner.get_best_hyperparameters(1)[0]

print(f"Best Hyperparameters for The Very Hungry Caterpillar:", best_hp_lstm_model.values)
# Out:
# Best Hyperparameters for The Very Hungry Caterpillar: {'input_unit': 28, 'n_layers': 1, 'lstm_0_units': 36, 'layer_2_neurons': 116, 'Dropout_rate': 0.4, 'dense_activation': 'relu', 'lstm_1_units': 4, 'lstm_2_units': 28, 'lstm_3_units': 116}

# %%
window_lstm = x_train_lstm[-1].copy()

forecast_lstm = []

for i in range(32):

  predictions_lstm = best_lstm_model.predict(window_lstm.reshape((1, lookback, 1)))

  forecast_lstm.append(predictions_lstm)

  window_lstm = np.vstack((window_lstm[1:], predictions_lstm))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step

# %%
forecast_lstm_inverse = scaler.inverse_transform(np.array(forecast_lstm).reshape(-1,1))

# %%
plot_forecast(ts_train, ts_test, forecast_lstm_inverse, 'LSTM Forecast for The Very Hungry Caterpillar')

# %%
plot_forecast_zoom(ts_train, ts_test, forecast_lstm_inverse, 'LSTM Forecast for The Very Hungry Caterpillar')

# %%
#Evaluate
evaluate_forecast(ts_test, forecast_lstm_inverse)
# Out:
# MAE: 486.58
# RMSE: 608.41
# MAPE: 23.85%
# (486.5824890136719, 608.4091186523438, 23.852121829986572)

# %% [markdown]
# In both cases, the LSTM model produces a smooth forecast that underrepresents the seasonal variations present in the data. This behaviour is similar to that observed with XGBoost, although XGBoost performs better both visually and in terms of MAPE score.

# %% [markdown]
# # **Sequential Hybrid**

# %%
#Split the residuals from the SARIMA model
ts_train_sh = residuals_aa[:-32]
ts_test_sh = residuals_aa[-32:]

# Use a separate scaler for the SARIMA residuals
scaler_residuals = MinMaxScaler()
sarima_resid_scaled = scaler_residuals.fit_transform(ts_train_sh.values.reshape(-1, 1))

# Create input sequences for the LSTM on residuals
x_res, y_res = create_input_sequence(lookback, 1, sarima_resid_scaled)

# Perform KerasTuner search for the LSTM on residuals
# Define the directory and project name
tuner_dir_hybrid = 'lstm_tuning_hybrid'
project_name_hybrid = 'sales_forecast_hybrid'
full_path_hybrid = os.path.join(tuner_dir_hybrid, project_name_hybrid)

# Remove the existing KerasTuner project directory to force a fresh search.
if os.path.exists(full_path_hybrid):
    shutil.rmtree(full_path_hybrid)

tuner_s_hybrid = kt.RandomSearch(
    tuned_model,
    objective='mse',
    max_trials=10,
    executions_per_trial=1,
    directory=tuner_dir_hybrid,
    project_name=project_name_hybrid,
    seed=seed
)

tuner_s_hybrid.search(
    x=x_res,
    y=y_res,
    epochs=20,
    validation_split=0.2,
    batch_size=32,
    verbose=1
)

best_s_hybrid_model = tuner_s_hybrid.get_best_models(num_models=1)[0]
best_hp_s_hybrid = tuner_s_hybrid.get_best_hyperparameters(1)[0]

print(f"Best Hyperparameters for The Very Hungry Caterpillar (tuned Sequential hybrid model):", best_hp_s_hybrid.values)

# Train the best Sequencial hybrid LSTM model residuals
history_s_hybrid = best_s_hybrid_model.fit(x_res, y_res, epochs=50, batch_size=32, validation_split=0.2, verbose=1)

# Forecast the residuals using the trained LSTM model
window_s_hybrid = x_res[-1].copy()
forecast_s_hybrid = []

for i in range(32):
  predictions_s_hybrid = best_s_hybrid_model.predict(window_s_hybrid.reshape((1, lookback, 1)), verbose=1)
  forecast_s_hybrid.append(predictions_s_hybrid)
  window_s_hybrid = np.vstack((window_s_hybrid[1:], predictions_s_hybrid))

# Inverse transform the LSTM residual forecasts using the scaler for residuals
forecast_s_hybrid_unscaled = scaler_residuals.inverse_transform(np.array(forecast_s_hybrid).reshape(-1,1))

# Create a Pandas Series with the correct index for the LSTM residual forecasts
forecast_s_hybrid_series = pd.Series(forecast_s_hybrid_unscaled.flatten(), index=ts_test.index)

# Ensure auto_arima_forecast has the same index as ts_test for correct element-wise addition
auto_arima_forecast_aligned = pd.Series(auto_arima_forecast.values, index=ts_test.index)

# Combine SARIMA forecast with LSTM residual forecast
combined_s_hybrid_forecast = auto_arima_forecast_aligned + forecast_s_hybrid_series
# Out:
# Trial 10 Complete [00h 00m 42s]
# mse: 0.00954099465161562
#
# Best mse So Far: 0.008224277757108212
# Total elapsed time: 00h 07m 52s
# Best Hyperparameters for The Very Hungry Caterpillar (tuned Sequential hybrid model): {'input_unit': 68, 'n_layers': 1, 'lstm_0_units': 60, 'layer_2_neurons': 28, 'Dropout_rate': 0.4, 'dense_activation': 'sigmoid'}
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0181 - val_mse: 0.0181
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step

# %%
plot_forecast(ts_train, ts_test, combined_s_hybrid_forecast, 'Sequential Hybrid Forecast for The Very Hungry Caterpillar')

# %%
plot_forecast_zoom(ts_train, ts_test, combined_s_hybrid_forecast, 'Sequential Hybrid Forecast for The Very Hungry Caterpillar')

# %%
#Evaluate
evaluate_forecast(ts_test, combined_s_hybrid_forecast)
# Out:
# MAE: 351.94
# RMSE: 429.85
# MAPE: 17.13%
# (351.9395495235939, 429.85019024687085, 17.12729920433945)

# %% [markdown]
# Using a hybrid SARIMA–LSTM model, the results are notably improved compared to the standalone machine learning and deep learning approaches, with better capture of both trend and seasonal components. However, the MAPE scores are only marginally better than those achieved by the Auto ARIMA models alone

# %% [markdown]
# # **Parallel Hybrid**

# %%
combined_forecast_values = (auto_arima_forecast.values + forecast_lstm_inverse.flatten()) / 2
parallel_forecast = pd.Series(combined_forecast_values, index=forecast_index)

# %%
plot_forecast(ts_train, ts_test, parallel_forecast, 'Parallel Hybrid Forecast for The Very Hungry Caterpillar')

# %%
plot_forecast_zoom(ts_train, ts_test, parallel_forecast, 'Parallel Hybrid Forecast for The Very Hungry Caterpillar')

# %%
#Evaluate
evaluate_forecast(ts_test, parallel_forecast)
# Out:
# MAE: 381.81
# RMSE: 476.88
# MAPE: 18.97%
# (381.8102575694737, 476.8807205259123, 18.973274833797092)

# %%
#Best Weights
best_weight = None
best_mae = float('inf')

for w in np.arange(0, 1.1, 0.05):
  combined_forecast_values = (w * auto_arima_forecast.values + (1 - w) * np.array(forecast_lstm).flatten())
  mae_parallel = mean_absolute_error(ts_test, combined_forecast_values)

  if mae_parallel < best_mae:
    best_mae = mae_parallel
    best_weight = w

print(f"Best Weight for The Very Hungry Caterpillar: {best_weight}")
print(f"Best MAE for The Very Hungry Caterpillar: {best_mae}")
# Out:
# Best Weight for The Very Hungry Caterpillar: 1.05
# Best MAE for The Very Hungry Caterpillar: 334.18861405897405

# %%
best_parallel_hybrid = (
    best_weight * auto_arima_forecast.values
    + (1 - best_weight) * np.array(forecast_lstm).flatten()
)

# %%
plot_forecast(ts_train, ts_test, best_parallel_hybrid, 'Parallel Hybrid Forecast for The Very Hungry Caterpillar')

# %%
plot_forecast_zoom(ts_train, ts_test, best_parallel_hybrid, 'Parallel Hybrid Forecast for The Very Hungry Caterpillar')

# %%
#Evaluate
evaluate_forecast(ts_test, best_parallel_hybrid)
# Out:
# MAE: 334.19
# RMSE: 428.37
# MAPE: 17.07%
# (334.18861405897405, 428.3714531515665, 17.07079532152009)

# %% [markdown]
# When comparing approaches, combining SARIMA and LSTM and applying weighted tuning produces better results than using SARIMA outputs alone to train an LSTM model. In both cases, the forecasts closely follow the overall pattern of the test data.

# %% [markdown]
# # **SARIMA (Monthly)**

# %%
#split the data
monthly_ts_train = book_monthly['Volume'][:-8]
monthly_ts_test = book_monthly['Volume'][-8:]

# %%
#Find the seasonal period
smgraphics.tsa.plot_acf(monthly_ts_train, lags=24)
plt.vlines(x=12, ymin=-0.5, ymax=0.5, colors='red', linestyle='--')
plt.show()

# %%
#Monthly Model
#SARIMAX(1, 0, 0)x(0, 1, [1], 52) best model from sarima

monthly_sarima = SARIMAX(monthly_ts_train, order=(1, 0, 0), seasonal_order=(0, 1, 1, 12))

monthly_sarima_fit = monthly_sarima.fit()

# %%
forecast_monthly_sarima_index = monthly_ts_test.index

sarima_forecast_result = monthly_sarima_fit.get_forecast(steps=len(monthly_ts_test))
forecast_monthly_sarima = sarima_forecast_result.predicted_mean

# Get confidence intervals for the same number of steps as the forecast.
forecast_monthly_sarima_ci = sarima_forecast_result.conf_int()

#create a date index for the forecasts that matches the test set.
forecast_index = monthly_ts_test.index

#plot the results
plt.figure(figsize=(12, 6))
plt.plot(monthly_ts_train.index, monthly_ts_train, label='Training Data')
plt.plot(monthly_ts_test.index, monthly_ts_test, label='Test Data', color='orange')
plt.plot(forecast_monthly_sarima_index, forecast_monthly_sarima, label='SARIMA Forecast', color='green')
plt.fill_between(forecast_monthly_sarima_index, forecast_monthly_sarima_ci.iloc[:, 0], forecast_monthly_sarima_ci.iloc[:, 1], color='green', alpha=0.2)
plt.title('SARIMA Monthly Forecast for The Very Hungry Caterpillar')
plt.xlabel('Date')
plt.ylabel('Sales Volume')
plt.legend()
plt.show()

# %%
#Zoom in for a better look.
plt.figure(figsize=(12, 6))
plt.plot(monthly_ts_train.index, monthly_ts_train, label='Training Data')
plt.plot(monthly_ts_test.index, monthly_ts_test, label='Test Data', color='orange')
plt.plot(forecast_monthly_sarima_index, forecast_monthly_sarima, label='SARIMA Forecast', color='green')
plt.fill_between(forecast_monthly_sarima_index, forecast_monthly_sarima_ci.iloc[:, 0], forecast_monthly_sarima_ci.iloc[:, 1], color='green', alpha=0.2)
plt.xlim(pd.Timestamp("2023-01-01", None))
plt.title('SARIMA Monthly Forecast for The Very Hungry Caterpillar')
plt.xlabel('Date')
plt.ylabel('Sales Volume')
plt.legend()
plt.show()

# %%
#Evaluate
evaluate_forecast(monthly_ts_test, forecast_monthly_sarima)
# Out:
# MAE: 1839.84
# RMSE: 2838.88
# MAPE: 16.21%
# (1839.8363910532566, 2838.877864862204, 16.213708325064314)

# %% [markdown]
# Using the monthly SARIMA model, both forecasts appear visually accurate. However, the MAPE scores suggest differing performance. The Very Hungry Caterpillar achieves a best MAPE of 16.21%, whereas The Alchemist records a higher error of 35.96%.

# %% [markdown]
# # **XGBoost (Monthly)**

# %%
monthly_lagged = create_lag_features(monthly_ts_train, 26)

# %%
x_train_monthly = monthly_lagged.drop(columns=['y'])
y_train_monthly = monthly_lagged['y']

# %%
#Best Hyperparameters for The Very Hungry Caterpillar:
#window_length     26.000000
#max_depth          3.000000
#learning_rate      0.100000
#n_estimators     200.000000
#cv_mae           291.192816
#Name: 11, dtype: float64

monthly_model = XGBRegressor(n_estimators=200, learning_rate=0.1, max_depth=3, window_length=26)
monthly_model.fit(x_train_monthly, y_train_monthly)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=200,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
def predict_next_xgb_monthly(history):
    x_input_monthly = np.array(history[-1:-best_window_xgb-1:-1]).reshape(1, -1)
    return monthly_model.predict(x_input_monthly)[0]

forecast_monthly = recursive_forecast(monthly_ts_train, 8, predict_next_xgb_monthly)

# %%
forecast_monthly_series = pd.Series(forecast_monthly, index=monthly_ts_test.index)

# %%
plot_forecast(monthly_ts_train, monthly_ts_test, forecast_monthly_series, 'XGBoost (Monthly) Forecast for The Very Hungry Caterpillar')

# %%
plot_forecast_zoom(monthly_ts_train, monthly_ts_test, forecast_monthly_series, 'XGBoost (Monthly) Forecast for The Very Hungry Caterpillar')

# %%
#Evaluate
evaluate_forecast(monthly_ts_test, forecast_monthly_series)
# Out:
# MAE: 1915.84
# RMSE: 2573.48
# MAPE: 16.74%
# (1915.84375, 2573.481201171875, 16.737109422683716)

# %% [markdown]
# Similar to the monthly SARIMA results, the XGBoost model performs well for The Very Hungry Caterpillar but shows weaker performance for The Alchemist, indicating that the model generalises more effectively to one series than the other.

# %% [markdown]
# # **Comparison**

# %%
# Weekly Models
mae_arima, rmse_arima, mape_arima = evaluate_forecast(ts_test, auto_arima_forecast)
mae_xgb, rmse_xgb, mape_xgb = evaluate_forecast(ts_test, forecast_best_xgb)
mae_lstm, rmse_lstm, mape_lstm = evaluate_forecast(ts_test, forecast_lstm_inverse)
mae_seq_hybrid, rmse_seq_hybrid, mape_seq_hybrid = evaluate_forecast(ts_test, combined_s_hybrid_forecast)
mae_par_hybrid, rmse_par_hybrid, mape_par_hybrid = evaluate_forecast(ts_test, best_parallel_hybrid)

# Monthly Models
mae_monthly_sarima, rmse_monthly_sarima, mape_monthly_sarima = evaluate_forecast(monthly_ts_test, forecast_monthly_sarima)
mae_monthly_xgb, rmse_monthly_xgb, mape_monthly_xgb = evaluate_forecast(monthly_ts_test, forecast_monthly_series)


# Create a dictionary to store the results
results = {
    'Model': [
        'Auto ARIMA (Weekly)',
        'XGBoost (Weekly)',
        'LSTM (Weekly)',
        'Sequential Hybrid (Weekly)',
        'Parallel Hybrid (Weekly - Best Weights)',
        'SARIMA (Monthly)',
        'XGBoost (Monthly)'
    ],
    'MAE': [
        mae_arima,
        mae_xgb,
        mae_lstm,
        mae_seq_hybrid,
        mae_par_hybrid,
        mae_monthly_sarima,
        mae_monthly_xgb
    ],
    'RMSE': [
        rmse_arima,
        rmse_xgb,
        rmse_lstm,
        rmse_seq_hybrid,
        rmse_par_hybrid,
        rmse_monthly_sarima,
        rmse_monthly_xgb
    ],
    'MAPE (%)': [
        mape_arima,
        mape_xgb,
        mape_lstm,
        mape_seq_hybrid,
        mape_par_hybrid,
        mape_monthly_sarima,
        mape_monthly_xgb
    ]
}

# Create a DataFrame from the results dictionary
comparison_df = pd.DataFrame(results)

# Display the DataFrame
display(comparison_df)
# Out:
# MAE: 354.04
# RMSE: 430.98
# MAPE: 17.17%
# MAE: 609.74
# RMSE: 776.93
# MAPE: 26.89%
# MAE: 486.58
# RMSE: 608.41
# MAPE: 23.85%
# MAE: 351.94
# RMSE: 429.85
# MAPE: 17.13%
# MAE: 334.19
# RMSE: 428.37
# MAPE: 17.07%
# MAE: 1839.84
# RMSE: 2838.88
# MAPE: 16.21%
# MAE: 1915.84
# RMSE: 2573.48
# MAPE: 16.74%
#                                      Model          MAE         RMSE  \
# 0                      Auto ARIMA (Weekly)   354.039742   430.977114
# 1                         XGBoost (Weekly)   609.744076   776.929446
# 2                            LSTM (Weekly)   486.582489   608.409119
# 3               Sequential Hybrid (Weekly)   351.939550   429.850190
# 4  Parallel Hybrid (Weekly - Best Weights)   334.188614   428.371453
# 5                         SARIMA (Monthly)  1839.836391  2838.877865
# 6                        XGBoost (Monthly)  1915.843750  2573.481201
#
#     MAPE (%)
# 0  17.169508
# 1  26.890619
# 2  23.852122
# 3  17.127299
# 4  17.070795
# 5  16.213708
# 6  16.737109
